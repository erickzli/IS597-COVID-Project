# %%
import csv
import pandas as pd

# %%
#with open("United_States_COVID-19_Cases_and_Deaths_by_State_over_Time.csv", 'r') as file:
#    data = file.read()

# %%
#data

# %%
data = pd.read_csv('United_States_COVID-19_Cases_and_Deaths_by_State_over_Time.csv')

# %%
data
# Out:
#       submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 0          12/08/2020    OK     205999    171497.0     34502.0         0
# 1          08/29/2020    SD      12942         NaN         NaN       425
# 2          11/06/2020    SD      52639         NaN         NaN      1488
# 3          09/21/2020    MP         69        69.0         0.0         0
# 4          06/28/2020    PA      85988     83529.0      2459.0       492
# ...               ...   ...        ...         ...         ...       ...
# 25495      02/10/2021    OH     928631    803885.0    124746.0      3281
# 25496      09/05/2020    TN     162362    158070.0      4292.0      1765
# 25497      10/19/2020    KS      72968     67935.0      5033.0      2113
# 25498      12/05/2020    NY     368246         NaN         NaN      7532
# 25499      03/31/2020    IA        497         NaN         NaN        73
#
#        pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# 0            0.0       1752      1680.0        72.0          0         0.0
# 1            0.0        167       165.0         2.0          2         0.0
# 2           73.0        510       476.0        34.0         28         3.0
# 3            0.0          2         2.0         0.0          0         0.0
# 4           13.0       6614         NaN         NaN          8         4.0
# ...          ...        ...         ...         ...        ...         ...
# 25495      901.0      11856     10522.0      1334.0         63         9.0
# 25496       93.0       1862      1810.0        52.0         25         0.0
# 25497      179.0        872         NaN         NaN         13         0.0
# 25498        0.0      10274         NaN         NaN         57         0.0
# 25499        NaN          7         NaN         NaN          1         NaN
#
#                    created_at consent_cases consent_deaths
# 0      12/09/2020 02:45:40 PM         Agree          Agree
# 1      08/30/2020 02:49:52 PM           NaN          Agree
# 2      11/07/2020 02:45:17 PM           NaN          Agree
# 3      09/22/2020 01:51:57 PM         Agree          Agree
# 4      06/29/2020 02:37:31 PM         Agree      Not agree
# ...                       ...           ...            ...
# 25495  02/11/2021 02:50:55 PM         Agree          Agree
# 25496  09/06/2020 02:09:04 PM         Agree          Agree
# 25497  10/20/2020 02:59:27 PM         Agree            NaN
# 25498  12/06/2020 02:51:16 PM     Not agree      Not agree
# 25499  03/30/2020 04:22:39 PM     Not agree      Not agree
#
# [25500 rows x 15 columns]
