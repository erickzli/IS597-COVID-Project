# %% [markdown]
# ## Data Notes
# This is the same data pulled in the Pull API Data- SafeGraph ipynb file. I'll just copy and paste the same data information here.
#
# This data came from the Carnegie Mellon Delphi Epidata API (covidcast). The data source is SafeGraph. Here is the link to more information about the SafeGraph data: https://cmu-delphi.github.io/delphi-epidata/api/covidcast-signals/safegraph.html.
# I attempted to pull this data myself, but covidcast wasn't installing on the laptop I was running it on (since my normal laptop was being repaired at the time). Since I couldn't get it to install and time was a little tight, Erick ran my code (the code below) on his laptop and then transfered the collected datasets to my GitHub folder.
# The data that I now have from this is the following: the fraction of mobile devices that did not leave the area of their home on a 7-day trailing window average (com_home_week.csv), the fraction of mobile devices that spent more than 6 hours at a location other than home during the daytime (most likely a full time job) of a 7-day trailing window average (full_time_week.csv), and the fraction of dvices that spent between 3 and 6 hours at a location other than home during the daytime (most likely a part time job) on a 7-day trailing window average (part_time_week.csv).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
df_home = pd.read_csv('com_home_week.csv')
df_home
# Out:
#       geo_value                     signal  time_value       issue  lag  \
# 0            ak  completely_home_prop_7dav  2019-01-01  2021-01-05  735
# 1            al  completely_home_prop_7dav  2019-01-01  2021-01-05  735
# 2            ar  completely_home_prop_7dav  2019-01-01  2021-01-05  735
# 3            az  completely_home_prop_7dav  2019-01-01  2021-01-05  735
# 4            ca  completely_home_prop_7dav  2019-01-01  2021-01-05  735
# ...         ...                        ...         ...         ...  ...
# 38112        vt  completely_home_prop_7dav  2020-12-31  2021-01-31   31
# 38113        wa  completely_home_prop_7dav  2020-12-31  2021-01-31   31
# 38114        wi  completely_home_prop_7dav  2020-12-31  2021-01-31   31
# 38115        wv  completely_home_prop_7dav  2020-12-31  2021-01-31   31
# 38116        wy  completely_home_prop_7dav  2020-12-31  2021-01-31   31
#
#           value    stderr  sample_size geo_type data_source
# 0      0.437096  0.004173        523.0    state   safegraph
# 1      0.385781  0.001462       3434.0    state   safegraph
# 2      0.383693  0.001963       2145.0    state   safegraph
# 3      0.439120  0.001505       4162.0    state   safegraph
# 4      0.410421  0.000671      23117.0    state   safegraph
# ...         ...       ...          ...      ...         ...
# 38112  0.330110  0.001998       3651.0    state   safegraph
# 38113  0.353455  0.000579      33376.0    state   safegraph
# 38114  0.311591  0.000565      31329.0    state   safegraph
# 38115  0.316464  0.000976      11123.0    state   safegraph
# 38116  0.302852  0.001832       2870.0    state   safegraph
#
# [38117 rows x 10 columns]

# %%
#pip install plotly

# %%
df_full_time = pd.read_csv('full_time_week.csv')
df_full_time
# Out:
#       geo_value                    signal  time_value       issue  lag  \
# 0            ak  full_time_work_prop_7dav  2019-01-01  2021-01-06  736
# 1            al  full_time_work_prop_7dav  2019-01-01  2021-01-06  736
# 2            ar  full_time_work_prop_7dav  2019-01-01  2021-01-06  736
# 3            az  full_time_work_prop_7dav  2019-01-01  2021-01-06  736
# 4            ca  full_time_work_prop_7dav  2019-01-01  2021-01-06  736
# ...         ...                       ...         ...         ...  ...
# 38112        vt  full_time_work_prop_7dav  2020-12-31  2021-01-31   31
# 38113        wa  full_time_work_prop_7dav  2020-12-31  2021-01-31   31
# 38114        wi  full_time_work_prop_7dav  2020-12-31  2021-01-31   31
# 38115        wv  full_time_work_prop_7dav  2020-12-31  2021-01-31   31
# 38116        wy  full_time_work_prop_7dav  2020-12-31  2021-01-31   31
#
#           value    stderr  sample_size geo_type data_source
# 0      0.025282  0.000926        523.0    state   safegraph
# 1      0.018057  0.000192       3434.0    state   safegraph
# 2      0.021694  0.000315       2145.0    state   safegraph
# 3      0.017879  0.000202       4162.0    state   safegraph
# 4      0.020760  0.000111      23117.0    state   safegraph
# ...         ...       ...          ...      ...         ...
# 38112  0.044652  0.000549       3651.0    state   safegraph
# 38113  0.032008  0.000128      33376.0    state   safegraph
# 38114  0.042700  0.000168      31329.0    state   safegraph
# 38115  0.035792  0.000248      11123.0    state   safegraph
# 38116  0.034035  0.000447       2870.0    state   safegraph
#
# [38117 rows x 10 columns]

# %%
df_part_time = pd.read_csv('part_time_week.csv')
df_part_time
# Out:
#       geo_value                    signal  time_value       issue  lag  \
# 0            ak  part_time_work_prop_7dav  2019-01-01  2021-01-06  736
# 1            al  part_time_work_prop_7dav  2019-01-01  2021-01-06  736
# 2            ar  part_time_work_prop_7dav  2019-01-01  2021-01-06  736
# 3            az  part_time_work_prop_7dav  2019-01-01  2021-01-06  736
# 4            ca  part_time_work_prop_7dav  2019-01-01  2021-01-06  736
# ...         ...                       ...         ...         ...  ...
# 38112        vt  part_time_work_prop_7dav  2020-12-31  2021-01-31   31
# 38113        wa  part_time_work_prop_7dav  2020-12-31  2021-01-31   31
# 38114        wi  part_time_work_prop_7dav  2020-12-31  2021-01-31   31
# 38115        wv  part_time_work_prop_7dav  2020-12-31  2021-01-31   31
# 38116        wy  part_time_work_prop_7dav  2020-12-31  2021-01-31   31
#
#           value    stderr  sample_size geo_type data_source
# 0      0.030516  0.000951        523.0    state   safegraph
# 1      0.051753  0.000496       3434.0    state   safegraph
# 2      0.051756  0.000682       2145.0    state   safegraph
# 3      0.034720  0.000371       4162.0    state   safegraph
# 4      0.037865  0.000178      23117.0    state   safegraph
# ...         ...       ...          ...      ...         ...
# 38112  0.060398  0.000702       3651.0    state   safegraph
# 38113  0.056374  0.000202      33376.0    state   safegraph
# 38114  0.084229  0.000278      31329.0    state   safegraph
# 38115  0.057176  0.000341      11123.0    state   safegraph
# 38116  0.077729  0.000837       2870.0    state   safegraph
#
# [38117 rows x 10 columns]

# %% [markdown]
# There are nulls in the standard deviation

# %%
df_home.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38117 entries, 0 to 38116
# Data columns (total 10 columns):
# geo_value      38117 non-null object
# signal         38117 non-null object
# time_value     38117 non-null object
# issue          38117 non-null object
# lag            38117 non-null int64
# value          38117 non-null float64
# stderr         38107 non-null float64
# sample_size    38117 non-null float64
# geo_type       38117 non-null object
# data_source    38117 non-null object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.9+ MB

# %% [markdown]
# There are nulls in the standard deviation

# %%
df_full_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38117 entries, 0 to 38116
# Data columns (total 10 columns):
# geo_value      38117 non-null object
# signal         38117 non-null object
# time_value     38117 non-null object
# issue          38117 non-null object
# lag            38117 non-null int64
# value          38117 non-null float64
# stderr         38107 non-null float64
# sample_size    38117 non-null float64
# geo_type       38117 non-null object
# data_source    38117 non-null object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.9+ MB

# %% [markdown]
# There are nulls in the standard deviation

# %%
df_part_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38117 entries, 0 to 38116
# Data columns (total 10 columns):
# geo_value      38117 non-null object
# signal         38117 non-null object
# time_value     38117 non-null object
# issue          38117 non-null object
# lag            38117 non-null int64
# value          38117 non-null float64
# stderr         38107 non-null float64
# sample_size    38117 non-null float64
# geo_type       38117 non-null object
# data_source    38117 non-null object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.9+ MB

# %%
df_home_apr_2020 = df_home.loc[df_home['time_value'] == '2020-04-01']
df_home_apr_2020
# Out:
#       geo_value                     signal  time_value       issue  lag  \
# 23712        ak  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23713        al  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23714        ar  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23715        az  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23716        ca  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23717        co  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23718        ct  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23719        dc  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23720        de  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23721        fl  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23722        ga  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23723        hi  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23724        ia  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23725        id  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23726        il  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23727        in  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23728        ks  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23729        ky  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23730        la  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23731        ma  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23732        md  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23733        me  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23734        mi  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23735        mn  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23736        mo  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23737        ms  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23738        mt  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23739        nc  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23740        nd  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23741        ne  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23742        nh  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23743        nj  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23744        nm  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23745        nv  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23746        ny  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23747        oh  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23748        ok  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23749        or  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23750        pa  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23751        pr  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23752        ri  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23753        sc  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23754        sd  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23755        tn  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23756        tx  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23757        ut  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23758        va  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23759        vt  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23760        wa  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23761        wi  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23762        wv  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23763        wy  completely_home_prop_7dav  2020-04-01  2021-01-05  279
#
#           value    stderr  sample_size geo_type data_source
# 23712  0.350711  0.002037       3644.0    state   safegraph
# 23713  0.293900  0.000569      24036.0    state   safegraph
# 23714  0.305745  0.000708      14985.0    state   safegraph
# 23715  0.378719  0.000578      29095.0    state   safegraph
# 23716  0.437852  0.000285     161763.0    state   safegraph
# 23717  0.420789  0.000729      24638.0    state   safegraph
# 23718  0.424682  0.000849      18042.0    state   safegraph
# 23719  0.437454  0.002440       3142.0    state   safegraph
# 23720  0.415097  0.001791       3932.0    state   safegraph
# 23721  0.383288  0.000354      79594.0    state   safegraph
# 23722  0.350735  0.000517      38645.0    state   safegraph
# 23723  0.387490  0.001411       5830.0    state   safegraph
# 23724  0.339766  0.000724      18388.0    state   safegraph
# 23725  0.369348  0.001254       6713.0    state   safegraph
# 23726  0.430065  0.000452      67708.0    state   safegraph
# 23727  0.388412  0.000553      33655.0    state   safegraph
# 23728  0.353364  0.000780      16389.0    state   safegraph
# 23729  0.336416  0.000651      22935.0    state   safegraph
# 23730  0.338237  0.000653      24060.0    state   safegraph
# 23731  0.440620  0.000695      34690.0    state   safegraph
# 23732  0.441386  0.000705      27330.0    state   safegraph
# 23733  0.356658  0.001378       7499.0    state   safegraph
# 23734  0.444537  0.000512      56792.0    state   safegraph
# 23735  0.409012  0.000689      28731.0    state   safegraph
# 23736  0.355688  0.000591      31514.0    state   safegraph
# 23737  0.286742  0.000711      15089.0    state   safegraph
# 23738  0.348924  0.001547       5857.0    state   safegraph
# 23739  0.349914  0.000504      42807.0    state   safegraph
# 23740  0.328650  0.001669       4004.0    state   safegraph
# 23741  0.335024  0.000867      11412.0    state   safegraph
# 23742  0.394939  0.001453       6444.0    state   safegraph
# 23743  0.489270  0.000558      43954.0    state   safegraph
# 23744  0.375657  0.001152      10097.0    state   safegraph
# 23745  0.409719  0.000930      12754.0    state   safegraph
# 23746  0.473943  0.000429     106073.0    state   safegraph
# 23747  0.402373  0.000418      64506.0    state   safegraph
# 23748  0.326406  0.000634      20722.0    state   safegraph
# 23749  0.413613  0.000822      18382.0    state   safegraph
# 23750  0.430798  0.000462      68040.0    state   safegraph
# 23751  0.564295  0.000909      17620.0    state   safegraph
# 23752  0.412657  0.001627       5639.0    state   safegraph
# 23753  0.311991  0.000644      21304.0    state   safegraph
# 23754  0.323833  0.001521       4572.0    state   safegraph
# 23755  0.337027  0.000552      28793.0    state   safegraph
# 23756  0.377877  0.000315     110321.0    state   safegraph
# 23757  0.370289  0.000987      11795.0    state   safegraph
# 23758  0.388398  0.000622      37115.0    state   safegraph
# 23759  0.370261  0.002151       3642.0    state   safegraph
# 23760  0.444487  0.000612      33339.0    state   safegraph
# 23761  0.408225  0.000615      31315.0    state   safegraph
# 23762  0.354619  0.001003      11134.0    state   safegraph
# 23763  0.336431  0.001818       2870.0    state   safegraph

# %%
df_home_clean = df_home_apr_2020.drop(df_home_apr_2020.index[[7, 18]])
df_home_clean
# Out:
#       geo_value                     signal  time_value       issue  lag  \
# 23712        ak  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23713        al  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23714        ar  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23715        az  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23716        ca  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23717        co  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23718        ct  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23720        de  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23721        fl  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23722        ga  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23723        hi  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23724        ia  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23725        id  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23726        il  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23727        in  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23728        ks  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23729        ky  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23731        ma  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23732        md  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23733        me  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23734        mi  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23735        mn  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23736        mo  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23737        ms  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23738        mt  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23739        nc  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23740        nd  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23741        ne  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23742        nh  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23743        nj  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23744        nm  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23745        nv  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23746        ny  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23747        oh  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23748        ok  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23749        or  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23750        pa  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23751        pr  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23752        ri  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23753        sc  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23754        sd  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23755        tn  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23756        tx  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23757        ut  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23758        va  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23759        vt  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23760        wa  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23761        wi  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23762        wv  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23763        wy  completely_home_prop_7dav  2020-04-01  2021-01-05  279
#
#           value    stderr  sample_size geo_type data_source
# 23712  0.350711  0.002037       3644.0    state   safegraph
# 23713  0.293900  0.000569      24036.0    state   safegraph
# 23714  0.305745  0.000708      14985.0    state   safegraph
# 23715  0.378719  0.000578      29095.0    state   safegraph
# 23716  0.437852  0.000285     161763.0    state   safegraph
# 23717  0.420789  0.000729      24638.0    state   safegraph
# 23718  0.424682  0.000849      18042.0    state   safegraph
# 23720  0.415097  0.001791       3932.0    state   safegraph
# 23721  0.383288  0.000354      79594.0    state   safegraph
# 23722  0.350735  0.000517      38645.0    state   safegraph
# 23723  0.387490  0.001411       5830.0    state   safegraph
# 23724  0.339766  0.000724      18388.0    state   safegraph
# 23725  0.369348  0.001254       6713.0    state   safegraph
# 23726  0.430065  0.000452      67708.0    state   safegraph
# 23727  0.388412  0.000553      33655.0    state   safegraph
# 23728  0.353364  0.000780      16389.0    state   safegraph
# 23729  0.336416  0.000651      22935.0    state   safegraph
# 23731  0.440620  0.000695      34690.0    state   safegraph
# 23732  0.441386  0.000705      27330.0    state   safegraph
# 23733  0.356658  0.001378       7499.0    state   safegraph
# 23734  0.444537  0.000512      56792.0    state   safegraph
# 23735  0.409012  0.000689      28731.0    state   safegraph
# 23736  0.355688  0.000591      31514.0    state   safegraph
# 23737  0.286742  0.000711      15089.0    state   safegraph
# 23738  0.348924  0.001547       5857.0    state   safegraph
# 23739  0.349914  0.000504      42807.0    state   safegraph
# 23740  0.328650  0.001669       4004.0    state   safegraph
# 23741  0.335024  0.000867      11412.0    state   safegraph
# 23742  0.394939  0.001453       6444.0    state   safegraph
# 23743  0.489270  0.000558      43954.0    state   safegraph
# 23744  0.375657  0.001152      10097.0    state   safegraph
# 23745  0.409719  0.000930      12754.0    state   safegraph
# 23746  0.473943  0.000429     106073.0    state   safegraph
# 23747  0.402373  0.000418      64506.0    state   safegraph
# 23748  0.326406  0.000634      20722.0    state   safegraph
# 23749  0.413613  0.000822      18382.0    state   safegraph
# 23750  0.430798  0.000462      68040.0    state   safegraph
# 23751  0.564295  0.000909      17620.0    state   safegraph
# 23752  0.412657  0.001627       5639.0    state   safegraph
# 23753  0.311991  0.000644      21304.0    state   safegraph
# 23754  0.323833  0.001521       4572.0    state   safegraph
# 23755  0.337027  0.000552      28793.0    state   safegraph
# 23756  0.377877  0.000315     110321.0    state   safegraph
# 23757  0.370289  0.000987      11795.0    state   safegraph
# 23758  0.388398  0.000622      37115.0    state   safegraph
# 23759  0.370261  0.002151       3642.0    state   safegraph
# 23760  0.444487  0.000612      33339.0    state   safegraph
# 23761  0.408225  0.000615      31315.0    state   safegraph
# 23762  0.354619  0.001003      11134.0    state   safegraph
# 23763  0.336431  0.001818       2870.0    state   safegraph

# %%
df_home_apr_2020_in = df_home_clean.reset_index(drop=True)
df_home_apr_2020_in
# Out:
#    geo_value                     signal  time_value       issue  lag  \
# 0         ak  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 1         al  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 2         ar  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 3         az  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 4         ca  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 5         co  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 6         ct  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 7         de  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 8         fl  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 9         ga  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 10        hi  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 11        ia  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 12        id  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 13        il  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 14        in  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 15        ks  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 16        ky  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 17        ma  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 18        md  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 19        me  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 20        mi  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 21        mn  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 22        mo  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 23        ms  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 24        mt  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 25        nc  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 26        nd  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 27        ne  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 28        nh  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 29        nj  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 30        nm  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 31        nv  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 32        ny  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 33        oh  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 34        ok  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 35        or  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 36        pa  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 37        pr  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 38        ri  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 39        sc  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 40        sd  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 41        tn  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 42        tx  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 43        ut  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 44        va  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 45        vt  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 46        wa  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 47        wi  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 48        wv  completely_home_prop_7dav  2020-04-01  2021-01-05  279
# 49        wy  completely_home_prop_7dav  2020-04-01  2021-01-05  279
#
#        value    stderr  sample_size geo_type data_source
# 0   0.350711  0.002037       3644.0    state   safegraph
# 1   0.293900  0.000569      24036.0    state   safegraph
# 2   0.305745  0.000708      14985.0    state   safegraph
# 3   0.378719  0.000578      29095.0    state   safegraph
# 4   0.437852  0.000285     161763.0    state   safegraph
# 5   0.420789  0.000729      24638.0    state   safegraph
# 6   0.424682  0.000849      18042.0    state   safegraph
# 7   0.415097  0.001791       3932.0    state   safegraph
# 8   0.383288  0.000354      79594.0    state   safegraph
# 9   0.350735  0.000517      38645.0    state   safegraph
# 10  0.387490  0.001411       5830.0    state   safegraph
# 11  0.339766  0.000724      18388.0    state   safegraph
# 12  0.369348  0.001254       6713.0    state   safegraph
# 13  0.430065  0.000452      67708.0    state   safegraph
# 14  0.388412  0.000553      33655.0    state   safegraph
# 15  0.353364  0.000780      16389.0    state   safegraph
# 16  0.336416  0.000651      22935.0    state   safegraph
# 17  0.440620  0.000695      34690.0    state   safegraph
# 18  0.441386  0.000705      27330.0    state   safegraph
# 19  0.356658  0.001378       7499.0    state   safegraph
# 20  0.444537  0.000512      56792.0    state   safegraph
# 21  0.409012  0.000689      28731.0    state   safegraph
# 22  0.355688  0.000591      31514.0    state   safegraph
# 23  0.286742  0.000711      15089.0    state   safegraph
# 24  0.348924  0.001547       5857.0    state   safegraph
# 25  0.349914  0.000504      42807.0    state   safegraph
# 26  0.328650  0.001669       4004.0    state   safegraph
# 27  0.335024  0.000867      11412.0    state   safegraph
# 28  0.394939  0.001453       6444.0    state   safegraph
# 29  0.489270  0.000558      43954.0    state   safegraph
# 30  0.375657  0.001152      10097.0    state   safegraph
# 31  0.409719  0.000930      12754.0    state   safegraph
# 32  0.473943  0.000429     106073.0    state   safegraph
# 33  0.402373  0.000418      64506.0    state   safegraph
# 34  0.326406  0.000634      20722.0    state   safegraph
# 35  0.413613  0.000822      18382.0    state   safegraph
# 36  0.430798  0.000462      68040.0    state   safegraph
# 37  0.564295  0.000909      17620.0    state   safegraph
# 38  0.412657  0.001627       5639.0    state   safegraph
# 39  0.311991  0.000644      21304.0    state   safegraph
# 40  0.323833  0.001521       4572.0    state   safegraph
# 41  0.337027  0.000552      28793.0    state   safegraph
# 42  0.377877  0.000315     110321.0    state   safegraph
# 43  0.370289  0.000987      11795.0    state   safegraph
# 44  0.388398  0.000622      37115.0    state   safegraph
# 45  0.370261  0.002151       3642.0    state   safegraph
# 46  0.444487  0.000612      33339.0    state   safegraph
# 47  0.408225  0.000615      31315.0    state   safegraph
# 48  0.354619  0.001003      11134.0    state   safegraph
# 49  0.336431  0.001818       2870.0    state   safegraph

# %%
#df_home_apr_2020_in['geo_value'].map(df_home_apr_2020_in['geo_value'])

# %%
fig = go.Figure(data = go.Choropleth(
    locations = df_home_apr_2020_in['geo_value'],
    z = df_home_apr_2020_in['value'].astype(float),
    locationmode = 'USA-states',
    colorscale = 'Reds',
    colorbar_title = "People Staying Home"))
fig.update_layout(
    title_text = 'People Staying Home',
    geo_scope = 'usa')
fig.show()
# Out:
# <div>                            <div id="7ba230fc-886a-41e8-b547-eeaa162a1aa7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ba230fc-886a-41e8-b547-eeaa162a1aa7")) {                    Plotly.newPlot(                        "7ba230fc-886a-41e8-b547-eeaa162a1aa7",                        [{"colorbar": {"title": {"text": "People Staying Home"}}, "colorscale": [[0.0, "rgb(255,245,240)"], [0.125, "rgb(254,224,210)"], [0.25, "rgb(252,187,161)"], [0.375, "rgb(252,146,114)"], [0.5, "rgb(251,106,74)"], [0.625, "rgb(239,59,44)"], [0.75, "rgb(203,24,29)"], [0.875, "rgb(165,15,21)"], [1.0, "rgb(103,0,13)"]], "locationmode": "USA-states", "locations": ["ak", "al", "ar", "az", "ca", "co", "ct", "de", "fl", "ga", "hi", "ia", "id", "il", "in", "ks", "ky", "ma", "md", "me", "mi", "mn", "mo", "ms", "mt", "nc", "nd", "ne", "nh", "nj", "nm", "nv", "ny", "oh", "ok", "or", "pa", "pr", "ri", "sc", "sd", "tn", "tx", "ut", "va", "vt", "wa", "wi", "wv", "wy"], "type": "choropleth", "z": [0.35071056938663, 0.29389988064603007, 0.30574513179, 0.37871944991701, 0.43785155211508, 0.42078908861204, 0.42468224268638, 0.41509746210484005, 0.38328811762519, 0.35073506790026, 0.3874900180009, 0.33976605506382, 0.3693479288707, 0.43006534074851, 0.38841214172672994, 0.35336386352547994, 0.33641612230154, 0.44062041149777004, 0.44138578969419, 0.35665843419087, 0.44453697551138, 0.40901181545353005, 0.35568782752621003, 0.28674210751911, 0.3489238783645, 0.34991387535335994, 0.32864959765819, 0.33502388259855, 0.3949385114553, 0.48926957354601003, 0.37565715166903996, 0.40971932610566, 0.47394338419307, 0.40237256387464004, 0.32640565389309006, 0.41361296957415, 0.4307980061165, 0.5642949676492399, 0.41265725035678996, 0.31199062942219, 0.32383251614134, 0.33702660796816997, 0.37787665242738, 0.37028945570413, 0.38839772603392, 0.37026112031024, 0.44448658663143004, 0.40822497162253, 0.3546186730215, 0.33643069406373]}],                        {"geo": {"scope": "usa"}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d ...

# %%
# example
import plotly.graph_objects as go

import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_us_ag_exports.csv')

fig = go.Figure(data=go.Choropleth(
    locations=df['code'], # Spatial coordinates
    z = df['total exports'].astype(float), # Data to be color-coded
    locationmode = 'USA-states', # set of locations match entries in `locations`
    colorscale = 'Reds',
    colorbar_title = "Millions USD",
))

fig.update_layout(
    title_text = '2011 US Agriculture Exports by State',
    geo_scope='usa', # limite map scope to USA
)

fig.show()

# %%
df_home_IL = df_home.loc[df_home['geo_value'] == 'il']
df_home_IL
# Out:
#       geo_value                     signal  time_value       issue  lag  \
# 14           il  completely_home_prop_7dav  2019-01-01  2021-01-05  735
# 66           il  completely_home_prop_7dav  2019-01-02  2021-01-05  734
# 118          il  completely_home_prop_7dav  2019-01-03  2021-01-05  733
# 170          il  completely_home_prop_7dav  2019-01-04  2021-01-05  732
# 222          il  completely_home_prop_7dav  2019-01-05  2021-01-05  731
# ...         ...                        ...         ...         ...  ...
# 37856        il  completely_home_prop_7dav  2020-12-27  2021-01-31   35
# 37912        il  completely_home_prop_7dav  2020-12-28  2021-01-31   34
# 37967        il  completely_home_prop_7dav  2020-12-29  2021-01-31   33
# 38022        il  completely_home_prop_7dav  2020-12-30  2021-01-31   32
# 38077        il  completely_home_prop_7dav  2020-12-31  2021-01-31   31
#
#           value    stderr  sample_size geo_type data_source
# 14     0.406473  0.000961       9679.0    state   safegraph
# 66     0.389479  0.000720      19357.0    state   safegraph
# 118    0.374622  0.000603      29035.0    state   safegraph
# 170    0.360392  0.000535      38714.0    state   safegraph
# 222    0.361637  0.000480      48392.0    state   safegraph
# ...         ...       ...          ...      ...         ...
# 37856  0.310295  0.000419      67702.0    state   safegraph
# 37912  0.314623  0.000415      67707.0    state   safegraph
# 37967  0.320477  0.000408      67709.0    state   safegraph
# 38022  0.327408  0.000401      67709.0    state   safegraph
# 38077  0.328079  0.000398      67713.0    state   safegraph
#
# [731 rows x 10 columns]

# %%
plt.plot(df_home_IL['time_value'], df_home_IL['value'], label = 'Stay Home')
#plt.plot(df_IL_2019['submission_date'], df_IL_2019['tot_cases'], label = 'Total Cases')
plt.xlabel('Date')
plt.xticks(rotation = 90)
plt.ylabel('Count')
plt.title('Stay Home')
#plt.grid(True)
plt.legend()
plt.figure(figsize = (10, 5))

plt.savefig('test_fig.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
df_home_IL_2019 = df_home_IL.loc[df_home_IL['time_value'] < '2020-01-01']
df_home_IL_2019
# Out:
#       geo_value                     signal  time_value       issue  lag  \
# 14           il  completely_home_prop_7dav  2019-01-01  2021-01-05  735
# 66           il  completely_home_prop_7dav  2019-01-02  2021-01-05  734
# 118          il  completely_home_prop_7dav  2019-01-03  2021-01-05  733
# 170          il  completely_home_prop_7dav  2019-01-04  2021-01-05  732
# 222          il  completely_home_prop_7dav  2019-01-05  2021-01-05  731
# ...         ...                        ...         ...         ...  ...
# 18734        il  completely_home_prop_7dav  2019-12-27  2021-01-05  375
# 18786        il  completely_home_prop_7dav  2019-12-28  2021-01-05  374
# 18838        il  completely_home_prop_7dav  2019-12-29  2021-01-05  373
# 18890        il  completely_home_prop_7dav  2019-12-30  2021-01-05  372
# 18942        il  completely_home_prop_7dav  2019-12-31  2021-01-05  371
#
#           value    stderr  sample_size geo_type data_source
# 14     0.406473  0.000961       9679.0    state   safegraph
# 66     0.389479  0.000720      19357.0    state   safegraph
# 118    0.374622  0.000603      29035.0    state   safegraph
# 170    0.360392  0.000535      38714.0    state   safegraph
# 222    0.361637  0.000480      48392.0    state   safegraph
# ...         ...       ...          ...      ...         ...
# 18734  0.285050  0.000375      67723.0    state   safegraph
# 18786  0.285078  0.000374      67720.0    state   safegraph
# 18838  0.287914  0.000376      67717.0    state   safegraph
# 18890  0.290877  0.000376      67717.0    state   safegraph
# 18942  0.288927  0.000377      67717.0    state   safegraph
#
# [365 rows x 10 columns]

# %%
plt.plot(df_home_IL_2019['time_value'], df_home_IL_2019['value'], label = 'Stay Home')
plt.xlabel('Date')
plt.xticks(['2019-01-01', '2019-03-01', '2019-06-01', '2019-09-01', '2019-12-01'], rotation = 90)
plt.ylabel('Count')
plt.title('Fraction of Mobile Devices that Did Not Leave Home on a 7-Day Moving Average in 2019')
plt.grid(False)
#plt.legend()

plt.savefig('com_home_week_IL_2019.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
df_home_IL_2020 = df_home_IL.loc[df_home_IL['time_value'] >= '2020-01-01']
df_home_IL_2020
# Out:
#       geo_value                     signal  time_value       issue  lag  \
# 18994        il  completely_home_prop_7dav  2020-01-01  2021-01-05  370
# 19046        il  completely_home_prop_7dav  2020-01-02  2021-01-05  369
# 19098        il  completely_home_prop_7dav  2020-01-03  2021-01-05  368
# 19150        il  completely_home_prop_7dav  2020-01-04  2021-01-05  367
# 19202        il  completely_home_prop_7dav  2020-01-05  2021-01-05  366
# ...         ...                        ...         ...         ...  ...
# 37856        il  completely_home_prop_7dav  2020-12-27  2021-01-31   35
# 37912        il  completely_home_prop_7dav  2020-12-28  2021-01-31   34
# 37967        il  completely_home_prop_7dav  2020-12-29  2021-01-31   33
# 38022        il  completely_home_prop_7dav  2020-12-30  2021-01-31   32
# 38077        il  completely_home_prop_7dav  2020-12-31  2021-01-31   31
#
#           value    stderr  sample_size geo_type data_source
# 18994  0.282386  0.000362      67716.0    state   safegraph
# 19046  0.280231  0.000359      67716.0    state   safegraph
# 19098  0.278357  0.000358      67719.0    state   safegraph
# 19150  0.278955  0.000356      67716.0    state   safegraph
# 19202  0.280190  0.000356      67718.0    state   safegraph
# ...         ...       ...          ...      ...         ...
# 37856  0.310295  0.000419      67702.0    state   safegraph
# 37912  0.314623  0.000415      67707.0    state   safegraph
# 37967  0.320477  0.000408      67709.0    state   safegraph
# 38022  0.327408  0.000401      67709.0    state   safegraph
# 38077  0.328079  0.000398      67713.0    state   safegraph
#
# [366 rows x 10 columns]

# %%
plt.plot(df_home_IL_2020['time_value'], df_home_IL_2020['value'], label = 'Stay Home', color = 'orange')
plt.xlabel('Date')
plt.xticks(['2020-01-01', '2020-03-01', '2020-06-01', '2020-09-01', '2020-12-01'], rotation = 90)
plt.ylabel('Count')
plt.title('Fraction of Mobile Devices that Did Not Leave Home on a 7-Day Moving Average in 2020')
plt.grid(False)
#plt.legend()

plt.savefig('com_home_week_IL_2020.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
df_ft_IL = df_full_time.loc[df_full_time['geo_value'] == 'il']
df_ft_IL
# Out:
#       geo_value                    signal  time_value       issue  lag  \
# 14           il  full_time_work_prop_7dav  2019-01-01  2021-01-06  736
# 66           il  full_time_work_prop_7dav  2019-01-02  2021-01-06  735
# 118          il  full_time_work_prop_7dav  2019-01-03  2021-01-06  734
# 170          il  full_time_work_prop_7dav  2019-01-04  2021-01-06  733
# 222          il  full_time_work_prop_7dav  2019-01-05  2021-01-06  732
# ...         ...                       ...         ...         ...  ...
# 37856        il  full_time_work_prop_7dav  2020-12-27  2021-01-31   35
# 37912        il  full_time_work_prop_7dav  2020-12-28  2021-01-31   34
# 37967        il  full_time_work_prop_7dav  2020-12-29  2021-01-31   33
# 38022        il  full_time_work_prop_7dav  2020-12-30  2021-01-31   32
# 38077        il  full_time_work_prop_7dav  2020-12-31  2021-01-31   31
#
#           value    stderr  sample_size geo_type data_source
# 14     0.022628  0.000151       9679.0    state   safegraph
# 66     0.040802  0.000240      19357.0    state   safegraph
# 118    0.047910  0.000214      29035.0    state   safegraph
# 170    0.048975  0.000183      38714.0    state   safegraph
# 222    0.045507  0.000157      48392.0    state   safegraph
# ...         ...       ...          ...      ...         ...
# 37856  0.042871  0.000123      67702.0    state   safegraph
# 37912  0.043459  0.000124      67707.0    state   safegraph
# 37967  0.042373  0.000118      67709.0    state   safegraph
# 38022  0.041874  0.000116      67709.0    state   safegraph
# 38077  0.042864  0.000118      67713.0    state   safegraph
#
# [731 rows x 10 columns]

# %%
df_ft_IL_2019 = df_ft_IL.loc[df_ft_IL['time_value'] < '2020-01-01']
df_ft_IL_2019
# Out:
#       geo_value                    signal  time_value       issue  lag  \
# 14           il  full_time_work_prop_7dav  2019-01-01  2021-01-06  736
# 66           il  full_time_work_prop_7dav  2019-01-02  2021-01-06  735
# 118          il  full_time_work_prop_7dav  2019-01-03  2021-01-06  734
# 170          il  full_time_work_prop_7dav  2019-01-04  2021-01-06  733
# 222          il  full_time_work_prop_7dav  2019-01-05  2021-01-06  732
# ...         ...                       ...         ...         ...  ...
# 18734        il  full_time_work_prop_7dav  2019-12-27  2021-01-06  376
# 18786        il  full_time_work_prop_7dav  2019-12-28  2021-01-06  375
# 18838        il  full_time_work_prop_7dav  2019-12-29  2021-01-06  374
# 18890        il  full_time_work_prop_7dav  2019-12-30  2021-01-06  373
# 18942        il  full_time_work_prop_7dav  2019-12-31  2021-01-06  372
#
#           value    stderr  sample_size geo_type data_source
# 14     0.022628  0.000151       9679.0    state   safegraph
# 66     0.040802  0.000240      19357.0    state   safegraph
# 118    0.047910  0.000214      29035.0    state   safegraph
# 170    0.048975  0.000183      38714.0    state   safegraph
# 222    0.045507  0.000157      48392.0    state   safegraph
# ...         ...       ...          ...      ...         ...
# 18734  0.040511  0.000114      67723.0    state   safegraph
# 18786  0.039812  0.000113      67720.0    state   safegraph
# 18838  0.039185  0.000112      67717.0    state   safegraph
# 18890  0.039992  0.000119      67717.0    state   safegraph
# 18942  0.042037  0.000121      67717.0    state   safegraph
#
# [365 rows x 10 columns]

# %%
df_ft_IL_2020 = df_ft_IL.loc[df_ft_IL['time_value'] >= '2020-01-01']
df_ft_IL_2020
# Out:
#       geo_value                    signal  time_value       issue  lag  \
# 18994        il  full_time_work_prop_7dav  2020-01-01  2021-01-06  371
# 19046        il  full_time_work_prop_7dav  2020-01-02  2021-01-06  370
# 19098        il  full_time_work_prop_7dav  2020-01-03  2021-01-06  369
# 19150        il  full_time_work_prop_7dav  2020-01-04  2021-01-06  368
# 19202        il  full_time_work_prop_7dav  2020-01-05  2021-01-06  367
# ...         ...                       ...         ...         ...  ...
# 37856        il  full_time_work_prop_7dav  2020-12-27  2021-01-31   35
# 37912        il  full_time_work_prop_7dav  2020-12-28  2021-01-31   34
# 37967        il  full_time_work_prop_7dav  2020-12-29  2021-01-31   33
# 38022        il  full_time_work_prop_7dav  2020-12-30  2021-01-31   32
# 38077        il  full_time_work_prop_7dav  2020-12-31  2021-01-31   31
#
#           value    stderr  sample_size geo_type data_source
# 18994  0.039901  0.000115      67716.0    state   safegraph
# 19046  0.042823  0.000133      67716.0    state   safegraph
# 19098  0.044517  0.000139      67719.0    state   safegraph
# 19150  0.045392  0.000140      67716.0    state   safegraph
# 19202  0.046239  0.000139      67718.0    state   safegraph
# ...         ...       ...          ...      ...         ...
# 37856  0.042871  0.000123      67702.0    state   safegraph
# 37912  0.043459  0.000124      67707.0    state   safegraph
# 37967  0.042373  0.000118      67709.0    state   safegraph
# 38022  0.041874  0.000116      67709.0    state   safegraph
# 38077  0.042864  0.000118      67713.0    state   safegraph
#
# [366 rows x 10 columns]

# %%
df_pt_IL = df_part_time.loc[df_part_time['geo_value'] == 'il']
df_pt_IL
# Out:
#       geo_value                    signal  time_value       issue  lag  \
# 14           il  part_time_work_prop_7dav  2019-01-01  2021-01-06  736
# 66           il  part_time_work_prop_7dav  2019-01-02  2021-01-06  735
# 118          il  part_time_work_prop_7dav  2019-01-03  2021-01-06  734
# 170          il  part_time_work_prop_7dav  2019-01-04  2021-01-06  733
# 222          il  part_time_work_prop_7dav  2019-01-05  2021-01-06  732
# ...         ...                       ...         ...         ...  ...
# 37856        il  part_time_work_prop_7dav  2020-12-27  2021-01-31   35
# 37912        il  part_time_work_prop_7dav  2020-12-28  2021-01-31   34
# 37967        il  part_time_work_prop_7dav  2020-12-29  2021-01-31   33
# 38022        il  part_time_work_prop_7dav  2020-12-30  2021-01-31   32
# 38077        il  part_time_work_prop_7dav  2020-12-31  2021-01-31   31
#
#           value    stderr  sample_size geo_type data_source
# 14     0.046622  0.000311       9679.0    state   safegraph
# 66     0.066514  0.000315      19357.0    state   safegraph
# 118    0.075349  0.000273      29035.0    state   safegraph
# 170    0.078130  0.000237      38714.0    state   safegraph
# 222    0.075616  0.000209      48392.0    state   safegraph
# ...         ...       ...          ...      ...         ...
# 37856  0.082181  0.000193      67702.0    state   safegraph
# 37912  0.083111  0.000192      67707.0    state   safegraph
# 37967  0.081836  0.000187      67709.0    state   safegraph
# 38022  0.080410  0.000186      67709.0    state   safegraph
# 38077  0.080139  0.000184      67713.0    state   safegraph
#
# [731 rows x 10 columns]

# %%
df_pt_IL_2019 = df_pt_IL.loc[df_pt_IL['time_value'] < '2020-01-01']
df_pt_IL_2019
# Out:
#       geo_value                    signal  time_value       issue  lag  \
# 14           il  part_time_work_prop_7dav  2019-01-01  2021-01-06  736
# 66           il  part_time_work_prop_7dav  2019-01-02  2021-01-06  735
# 118          il  part_time_work_prop_7dav  2019-01-03  2021-01-06  734
# 170          il  part_time_work_prop_7dav  2019-01-04  2021-01-06  733
# 222          il  part_time_work_prop_7dav  2019-01-05  2021-01-06  732
# ...         ...                       ...         ...         ...  ...
# 18734        il  part_time_work_prop_7dav  2019-12-27  2021-01-06  376
# 18786        il  part_time_work_prop_7dav  2019-12-28  2021-01-06  375
# 18838        il  part_time_work_prop_7dav  2019-12-29  2021-01-06  374
# 18890        il  part_time_work_prop_7dav  2019-12-30  2021-01-06  373
# 18942        il  part_time_work_prop_7dav  2019-12-31  2021-01-06  372
#
#           value    stderr  sample_size geo_type data_source
# 14     0.046622  0.000311       9679.0    state   safegraph
# 66     0.066514  0.000315      19357.0    state   safegraph
# 118    0.075349  0.000273      29035.0    state   safegraph
# 170    0.078130  0.000237      38714.0    state   safegraph
# 222    0.075616  0.000209      48392.0    state   safegraph
# ...         ...       ...          ...      ...         ...
# 18734  0.091104  0.000199      67723.0    state   safegraph
# 18786  0.089780  0.000199      67720.0    state   safegraph
# 18838  0.088280  0.000197      67717.0    state   safegraph
# 18890  0.088502  0.000200      67717.0    state   safegraph
# 18942  0.088694  0.000199      67717.0    state   safegraph
#
# [365 rows x 10 columns]

# %%
df_pt_IL_2020 = df_pt_IL.loc[df_pt_IL['time_value'] >= '2020-01-01']
df_pt_IL_2020
# Out:
#       geo_value                    signal  time_value       issue  lag  \
# 18994        il  part_time_work_prop_7dav  2020-01-01  2021-01-06  371
# 19046        il  part_time_work_prop_7dav  2020-01-02  2021-01-06  370
# 19098        il  part_time_work_prop_7dav  2020-01-03  2021-01-06  369
# 19150        il  part_time_work_prop_7dav  2020-01-04  2021-01-06  368
# 19202        il  part_time_work_prop_7dav  2020-01-05  2021-01-06  367
# ...         ...                       ...         ...         ...  ...
# 37856        il  part_time_work_prop_7dav  2020-12-27  2021-01-31   35
# 37912        il  part_time_work_prop_7dav  2020-12-28  2021-01-31   34
# 37967        il  part_time_work_prop_7dav  2020-12-29  2021-01-31   33
# 38022        il  part_time_work_prop_7dav  2020-12-30  2021-01-31   32
# 38077        il  part_time_work_prop_7dav  2020-12-31  2021-01-31   31
#
#           value    stderr  sample_size geo_type data_source
# 18994  0.078430  0.000175      67716.0    state   safegraph
# 19046  0.079838  0.000184      67716.0    state   safegraph
# 19098  0.081009  0.000186      67719.0    state   safegraph
# 19150  0.081793  0.000187      67716.0    state   safegraph
# 19202  0.082655  0.000187      67718.0    state   safegraph
# ...         ...       ...          ...      ...         ...
# 37856  0.082181  0.000193      67702.0    state   safegraph
# 37912  0.083111  0.000192      67707.0    state   safegraph
# 37967  0.081836  0.000187      67709.0    state   safegraph
# 38022  0.080410  0.000186      67709.0    state   safegraph
# 38077  0.080139  0.000184      67713.0    state   safegraph
#
# [366 rows x 10 columns]

# %%
plt.plot(df_ft_IL_2019['time_value'], df_ft_IL_2019['value'], label = 'Full Time')
plt.plot(df_pt_IL_2019['time_value'], df_pt_IL_2019['value'], label = 'Part Time')
plt.xlabel('Date')
plt.xticks(['2019-01-01', '2019-03-01', '2019-06-01', '2019-09-01', '2019-12-01'], rotation = 90)
plt.ylabel('Count')
plt.title('People Working Possible Full Time and Part Time Jobs Requiring Leaving the House in 2019')
plt.grid(False)
plt.legend()

plt.savefig('ft_pt_week_IL_2019.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.plot(df_ft_IL_2020['time_value'], df_ft_IL_2020['value'], label = 'Full Time')
plt.plot(df_pt_IL_2020['time_value'], df_pt_IL_2020['value'], label = 'Part Time')
plt.xlabel('Date')
plt.xticks(['2020-01-01', '2020-03-01', '2020-06-01', '2020-09-01', '2020-12-01'], rotation = 90)
plt.ylabel('Count')
plt.title('People Working Possible Full Time and Part Time Jobs Requiring Leaving the House in 2020')
plt.grid(False)
plt.legend()

plt.savefig('ft_pt_week_IL_2020.png', dpi=300, bbox_inches='tight')
plt.show()
